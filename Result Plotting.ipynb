# %%
import matplotlib.pyplot as plt
import pickle
import glob

# %%
dir_1 = 'src/Run0_WithoutChauffer//history_save35.pickle'

# %%
f = open(dir_1,"rb")

# %%
hist = pickle.load(f)

# %%
x = hist['step']
y = hist["score"]

# %%
plt.xlabel("Iterations")
plt.ylabel("Reward")
plt.plot(x,y)

# %% [markdown]
# In the above plot a reward of 40+ could signify that the learning algorithm performed well. But this method was scrapped ebcause it does not use chauffer command (human guidance)

# %%
dir_2 = 'src/Run1_without_stepLearning/history_cmd10.pickle'

# %%
f = open(dir_2,"rb")
hist = pickle.load(f)

# %%
x = hist['step']
y = hist["score"]

# %%
plt.xlabel("Iterations")
plt.ylabel("Reward")
plt.plot(x,y)

# %% [markdown]
# There is an increase in the rewards, maybe more running is required. This uses chauffer commands along with processed data from radar.

# %%
dir_3 = 'src/Run2_WithRadarVectors/history_cmd35.pickle'

# %%
f = open(dir_3,"rb")
hist = pickle.load(f)

# %%
x = hist['step']
y = hist["score"]

# %%
plt.xlabel("Iterations")
plt.ylabel("Reward")
plt.plot(x,y)

# %% [markdown]
# This was run on unprocessed radar data. There are two more experiments that branch from this, use chauffer commands in rewards function rather than input. Use processed data or convert the raw data into meaningful semantics
